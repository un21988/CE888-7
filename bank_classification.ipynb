# %% [markdown]
# <a href="https://colab.research.google.com/github/un21988/CE888-7/blob/main/bank_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from zipfile import ZipFile
file_name = "/content/bank-additional.zip"

# %%
with ZipFile(file_name, 'r') as zip:
  zip.extractall()
  print('File has been extracted')
# Out:
# File has been extracted

# %%
dataframe = pd.read_csv("/content/bank-additional/bank-additional-full.csv", sep=";")
dataframe.head(3)
# Out:
#    age        job  marital  ... euribor3m nr.employed   y
# 0   56  housemaid  married  ...     4.857      5191.0  no
# 1   57   services  married  ...     4.857      5191.0  no
# 2   37   services  married  ...     4.857      5191.0  no
#
# [3 rows x 21 columns]

# %% [markdown]
# **process**

# %%
from sklearn import preprocessing
label = preprocessing.LabelEncoder()
dataframe.dtypes
# Out:
# age                 int64
# job                object
# marital            object
# education          object
# default            object
# housing            object
# loan               object
# contact            object
# month              object
# day_of_week        object
# duration            int64
# campaign            int64
# pdays               int64
# previous            int64
# poutcome           object
# emp.var.rate      float64
# cons.price.idx    float64
# cons.conf.idx     float64
# euribor3m         float64
# nr.employed       float64
# y                  object
# dtype: object

# %%
dataframe['job'].value_counts().plot(kind='bar')

# %%
#converting the lable into values by Encoding
obj_dataframe = dataframe.select_dtypes(include=['object']).copy()
Encoding = obj_dataframe.apply(label.fit_transform)
Encoding.head(10)
# Out:
#    job  marital  education  default  ...  month  day_of_week  poutcome  y
# 0    3        1          0        0  ...      6            1         1  0
# 1    7        1          3        1  ...      6            1         1  0
# 2    7        1          3        0  ...      6            1         1  0
# 3    0        1          1        0  ...      6            1         1  0
# 4    7        1          3        0  ...      6            1         1  0
# 5    7        1          2        1  ...      6            1         1  0
# 6    0        1          5        0  ...      6            1         1  0
# 7    1        1          7        1  ...      6            1         1  0
# 8    9        2          5        0  ...      6            1         1  0
# 9    7        2          3        0  ...      6            1         1  0
#
# [10 rows x 11 columns]

# %%
dataframe_dummies = pd.get_dummies(dataframe)
dataframe_dummies.head(10)
# Out:
#    age  duration  campaign  ...  poutcome_success  y_no  y_yes
# 0   56       261         1  ...                 0     1      0
# 1   57       149         1  ...                 0     1      0
# 2   37       226         1  ...                 0     1      0
# 3   40       151         1  ...                 0     1      0
# 4   56       307         1  ...                 0     1      0
# 5   45       198         1  ...                 0     1      0
# 6   59       139         1  ...                 0     1      0
# 7   41       217         1  ...                 0     1      0
# 8   24       380         1  ...                 0     1      0
# 9   25        50         1  ...                 0     1      0
#
# [10 rows x 65 columns]

# %%
#droping durating coloume
dataframe.drop('duration', axis=1, inplace=True)
dataframe.head(10)
# Out:
#    age          job  marital  ... euribor3m nr.employed   y
# 0   56    housemaid  married  ...     4.857      5191.0  no
# 1   57     services  married  ...     4.857      5191.0  no
# 2   37     services  married  ...     4.857      5191.0  no
# 3   40       admin.  married  ...     4.857      5191.0  no
# 4   56     services  married  ...     4.857      5191.0  no
# 5   45     services  married  ...     4.857      5191.0  no
# 6   59       admin.  married  ...     4.857      5191.0  no
# 7   41  blue-collar  married  ...     4.857      5191.0  no
# 8   24   technician   single  ...     4.857      5191.0  no
# 9   25     services   single  ...     4.857      5191.0  no
#
# [10 rows x 20 columns]

# %%
dataframe.drop(obj_dataframe, axis=1, inplace=True)
dataframe = pd.concat([dataframe, Encoding], axis=1, join='inner')
display(dataframe)
# Out:
#        age  campaign  pdays  previous  ...  month  day_of_week  poutcome  y
# 0       56         1    999         0  ...      6            1         1  0
# 1       57         1    999         0  ...      6            1         1  0
# 2       37         1    999         0  ...      6            1         1  0
# 3       40         1    999         0  ...      6            1         1  0
# 4       56         1    999         0  ...      6            1         1  0
# ...    ...       ...    ...       ...  ...    ...          ...       ... ..
# 41183   73         1    999         0  ...      7            0         1  1
# 41184   46         1    999         0  ...      7            0         1  0
# 41185   56         2    999         0  ...      7            0         1  0
# 41186   44         1    999         0  ...      7            0         1  1
# 41187   74         3    999         1  ...      7            0         0  0
#
# [41188 rows x 20 columns]

# %%
dataframe_Missing = dataframe.dropna( axis=0, how='all')
dataframe.columns
# Out:
# Index(['age', 'campaign', 'pdays', 'previous', 'emp.var.rate',
#        'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed', 'job',
#        'marital', 'education', 'default', 'housing', 'loan', 'contact',
#        'month', 'day_of_week', 'poutcome', 'y'],
#       dtype='object')

# %% [markdown]
# **Modeling:**

# %%
from sklearn.model_selection import train_test_split
x_axsis = dataframe[['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
       'contact', 'month', 'day_of_week', 'campaign', 'pdays', 'previous',
       'poutcome', 'emp.var.rate', 'cons.price.idx', 'cons.conf.idx',
       'euribor3m', 'nr.employed']]
y_axsis = dataframe['y']
X_train, X_test, y_train, y_test = train_test_split(x_axsis, y_axsis,stratify=y_axsis, test_size=0.20,random_state=50)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (32950, 19) (8238, 19) (32950,) (8238,)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
clfRF1 = RandomForestClassifier(max_depth=3,n_estimators=100, )
clfRF1.fit(x_axsis, y_axsis)
y_pred = clfRF1.predict(X_test)
accuracy= accuracy_score(y_test, y_pred)

print("we got the accuracy about ","{:.3f}".format(accuracy), "%")
# Out:
# we got the accuracy about  0.90 %

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
RFC=RandomForestClassifier(random_state=42)
param_grid = { 
    'n_estimators': [200, 250, 300 ],
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth' : [2,3,4],
    'criterion' :['gini', 'entropy']
}
CVRFC = GridSearchCV(estimator=RFC, param_grid=param_grid, cv= 5)
CVRFC.fit(x_axsis, y_axsis)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                               class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               max_samples=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators=100, n_jobs=None,
#                                               oob_score=False, random_state=42,
#                                               verbose=0, warm_start=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [2, 3, 4],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [200, 250, 300]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
y_pred_ = CVRFC.predict(X_test)
accuracy = accuracy_score ( y_test, y_pred_ )
print("we got the accuracy about ","{:.2f}".format(accuracy), "%")
# Out:
# we got the accuracy about  0.90 %

# %%
from matplotlib import pyplot
importance = clfRF1.feature_importances_

for i,j in enumerate(importance):
	print('F: %0d, S: %.5f' % (i,j))

pyplot.bar([x for x in range(len(importance))], importance,color='Red')
pyplot.show()
# Out:
# F: 0, S: 0.01360
# F: 1, S: 0.00014
# F: 2, S: 0.00074
# F: 3, S: 0.00048
# F: 4, S: 0.00146
# F: 5, S: 0.00000
# F: 6, S: 0.00005
# F: 7, S: 0.00706
# F: 8, S: 0.02108
# F: 9, S: 0.00148
# F: 10, S: 0.00097
# F: 11, S: 0.15489
# F: 12, S: 0.01144
# F: 13, S: 0.10793
# F: 14, S: 0.09550
# F: 15, S: 0.04427
# F: 16, S: 0.05354
# F: 17, S: 0.21776
# F: 18, S: 0.26761
